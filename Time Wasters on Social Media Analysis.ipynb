# %% [markdown]
# # **Time-Wasters on Social Media Dataset**
#
# **Overview**
#
# The "Time-Wasters on Social Media" dataset provides a comprehensive view of user behavior and engagement across multiple social media platforms. It includes information on demographics, socio-economic status, device usage, platform interactions, and content engagement metrics, capturing key measures such as total time spent, session counts, video engagement, addiction levels, productivity loss, and user satisfaction.
#
# The dataset was generated using synthetic data techniques with pandas, matplotlib, and seaborn to simulate realistic usage patterns for research and analysis. It is particularly useful for researchers, marketers, and social scientists seeking to understand how social media affects habits, productivity, and decision-making.

# %% [markdown]
# ## Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('Time-Wasters on Social Media.csv')
df
# Out:
#      UserID  Age  Gender       Location  Income   Debt  Owns Property  \
# 0         1   56    Male       Pakistan   82812   True           True
# 1         2   46  Female         Mexico   27999  False           True
# 2         3   32  Female  United States   42436  False           True
# 3         4   60    Male         Barzil   62963   True          False
# 4         5   25    Male       Pakistan   22096  False           True
# ..      ...  ...     ...            ...     ...    ...            ...
# 995     996   22    Male          India   74254   True           True
# 996     997   40  Female       Pakistan   27006  False          False
# 997     998   27    Male          India   94218   True           True
# 998     999   61    Male       Pakistan   85344   True          False
# 999    1000   19    Male          India   53840   True           True
#
#         Profession Demographics   Platform  ...  ProductivityLoss  \
# ...

# %% [markdown]
# ## Columns Description of Time Wasters on social media dataset
#
# * UserID: Unique identifier assigned to each user.
# * Age: The user's age.
# * Gender: The user's gender (e.g., male, female, non-binary).
# * Location: Geographic location of the user.
# * Income: The user's income level.
# * Debt: Amount of debt the user has.
# * Owns Property: Indicates whether the user owns property.
# * Profession: The user's occupation or job.
# * Demographics: Statistical data about the user (e.g., age, gender, income).
# * Platform: The platform the user is using (e.g., website, mobile app).
# * Total Time Spent: The total time the user spends on the platform.
# * Number of Sessions: The number of times the user has logged into the platform.
# * Video ID: Unique identifier for a video.
# * Video Category: The category or genre of the video.
# * Video Length: Duration of the video.
# * Engagement: User interaction with the video (e.g., likes, comments, shares).
# * Importance Score: A score indicating how important the video is to the user.
# * Time Spent On Video: The amount of time the user spends watching a video.
# * Number of Videos Watched: The total number of videos watched by the user.
# * Scroll Rate: The rate at which the user scrolls through content.
# * Frequency: How often the user engages with the platform.
# * Productivity Loss: The impact of platform usage on the user's productivity.
# * Satisfaction: The user's satisfaction level with the platform or content.
# * Watch Reason: The reason why the user is watching a video (e.g., entertainment, education).
# * Device Type: The type of device the user is using (e.g., smartphone, tablet, desktop).
# * OS: The operating system of the user's device (e.g., iOS, Android, Windows).
# * Watch Time: The time of day when the user watches videos.
# * Self Control: The user's ability to control their usage of the platform.
# * Addiction Level: The user's level of dependency on the platform.
# * Current Activity: What the user is doing while watching the video.
# * Connection Type: The type of internet connection the user has (e.g., Wi-Fi, cellular).

# %% [markdown]
# ## Information of Dataset
# * Columns = 31
# * Rows = 1000
# * Data types
#    * bool = 2
#    * int64 = 16
#    * object = 13

# %% [markdown]
# ## Objectives
#
# #### 1. Analyze Platform-Wise Usage Patterns
# Determine which social media platforms consume the most user time and identify trends across Facebook, Instagram, YouTube, and TikTok.
#
# #### 2. Assess Demographic Influences
# Examine the impact of age, gender, and income on social media usage, addiction levels, and productivity loss.
#
# #### 3. Evaluate Device, OS, and Connectivity Factors
# Investigate how different devices (smartphones, computers, tablets), operating systems, and connection types (Wi-Fi vs. mobile data) affect the amount of time spent on social media.
#
# #### 4. Study Content Engagement and Behavioral Impacts
# Understand how content type, video length, addiction, self-control, and watch reasons influence engagement, productivity loss, and overall social media time-wasting behavior.

# %%
df.dtypes
# Out:
# UserID                       int64
# Age                          int64
# Gender                      object
# Location                    object
# Income                       int64
# Debt                          bool
# Owns Property                 bool
# Profession                  object
# Demographics                object
# Platform                    object
# Total Time Spent             int64
# Number of Sessions           int64
# Video ID                     int64
# Video Category              object
# Video Length                 int64
# Engagement                   int64
# Importance Score             int64
# Time Spent On Video          int64
# Number of Videos Watched     int64
# Scroll Rate                  int64
# Frequency                   object
# ProductivityLoss             int64
# Satisfaction                 int64
# Watch Reason                object
# DeviceType                  object
# OS                          object
# Watch Time                  object
# ...

# %%
df.shape
# Out:
# (1000, 31)

# %%
df.size
# Out:
# 31000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 31 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   UserID                    1000 non-null   int64
#  1   Age                       1000 non-null   int64
#  2   Gender                    1000 non-null   object
#  3   Location                  1000 non-null   object
#  4   Income                    1000 non-null   int64
#  5   Debt                      1000 non-null   bool
#  6   Owns Property             1000 non-null   bool
#  7   Profession                1000 non-null   object
#  8   Demographics              1000 non-null   object
#  9   Platform                  1000 non-null   object
#  10  Total Time Spent          1000 non-null   int64
#  11  Number of Sessions        1000 non-null   int64
#  12  Video ID                  1000 non-null   int64
#  13  Video Category            1000 non-null   object
# ...

# %%
df.describe()
# Out:
#             UserID          Age        Income  Total Time Spent  \
# count  1000.000000  1000.000000   1000.000000       1000.000000
# mean    500.500000    40.986000  59524.213000        151.406000
# std     288.819436    13.497852  23736.212925         83.952637
# min       1.000000    18.000000  20138.000000         10.000000
# 25%     250.750000    29.000000  38675.250000         78.000000
# 50%     500.500000    42.000000  58805.000000        152.000000
# 75%     750.250000    52.000000  79792.250000        223.000000
# max    1000.000000    64.000000  99676.000000        298.000000
#
#        Number of Sessions     Video ID  Video Length   Engagement  \
# count         1000.000000  1000.000000   1000.000000  1000.000000
# mean            10.013000  4891.738000     15.214000  4997.159000
# std              5.380314  2853.144258      8.224953  2910.053701
# min              1.000000    11.000000      1.000000    15.000000
# ...

# %%
df.columns
# Out:
# Index(['UserID', 'Age', 'Gender', 'Location', 'Income', 'Debt',
#        'Owns Property', 'Profession', 'Demographics', 'Platform',
#        'Total Time Spent', 'Number of Sessions', 'Video ID', 'Video Category',
#        'Video Length', 'Engagement', 'Importance Score', 'Time Spent On Video',
#        'Number of Videos Watched', 'Scroll Rate', 'Frequency',
#        'ProductivityLoss', 'Satisfaction', 'Watch Reason', 'DeviceType', 'OS',
#        'Watch Time', 'Self Control', 'Addiction Level', 'CurrentActivity',
#        'ConnectionType'],
#       dtype='object')

# %%
df.nunique()
# Out:
# UserID                      1000
# Age                           47
# Gender                         3
# Location                      10
# Income                       996
# Debt                           2
# Owns Property                  2
# Profession                     9
# Demographics                   2
# Platform                       4
# Total Time Spent             278
# Number of Sessions            19
# Video ID                     947
# Video Category                 9
# Video Length                  29
# Engagement                   953
# Importance Score               9
# Time Spent On Video           29
# Number of Videos Watched      49
# Scroll Rate                   99
# Frequency                      4
# ProductivityLoss               9
# Satisfaction                   9
# Watch Reason                   4
# DeviceType                     3
# OS                             4
# Watch Time                    16
# Self Control                   8
# ...

# %%
df.ndim
# Out:
# 2

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Checking null values

# %%
df.isnull().sum()
# Out:
# UserID                      0
# Age                         0
# Gender                      0
# Location                    0
# Income                      0
# Debt                        0
# Owns Property               0
# Profession                  0
# Demographics                0
# Platform                    0
# Total Time Spent            0
# Number of Sessions          0
# Video ID                    0
# Video Category              0
# Video Length                0
# Engagement                  0
# Importance Score            0
# Time Spent On Video         0
# Number of Videos Watched    0
# Scroll Rate                 0
# Frequency                   0
# ProductivityLoss            0
# Satisfaction                0
# Watch Reason                0
# DeviceType                  0
# OS                          0
# Watch Time                  0
# Self Control                0
# Addiction Level             0
# CurrentActivity             0
# ConnectionType              0
# ...

# %%
df['Location']= df['Location'].replace("Barzil", "Brazil")

# %%
df
# Out:
#      UserID  Age  Gender       Location  Income   Debt  Owns Property  \
# 0         1   56    Male       Pakistan   82812   True           True
# 1         2   46  Female         Mexico   27999  False           True
# 2         3   32  Female  United States   42436  False           True
# 3         4   60    Male         Brazil   62963   True          False
# 4         5   25    Male       Pakistan   22096  False           True
# ..      ...  ...     ...            ...     ...    ...            ...
# 995     996   22    Male          India   74254   True           True
# 996     997   40  Female       Pakistan   27006  False          False
# 997     998   27    Male          India   94218   True           True
# 998     999   61    Male       Pakistan   85344   True          False
# 999    1000   19    Male          India   53840   True           True
#
#         Profession Demographics   Platform  ...  ProductivityLoss  \
# ...

# %%
df['Age'].value_counts().head(10)
# Out:
# Age
# 43    33
# 50    30
# 45    30
# 52    28
# 64    27
# 54    27
# 56    25
# 18    25
# 62    25
# 41    25
# Name: count, dtype: int64

# %%
df['Age'].value_counts().tail(10)
# Out:
# Age
# 37    18
# 57    17
# 59    17
# 48    16
# 55    16
# 44    16
# 35    16
# 24    14
# 63    13
# 60    12
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12,5))
df.boxplot()
plt.xticks(rotation=80)
plt.show()

# %% [markdown]
# * There is no outlirs in this data

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Male      514
# Female    322
# Other     164
# Name: count, dtype: int64

# %% [markdown]
# ## Platform-Wise Time Wasting

# %%
sns.barplot(x='Platform',y='Total Time Spent',data=df)
plt.show()

# %%
df.groupby("Platform")["Total Time Spent"].mean().plot(kind="pie",autopct="%1.0f%%",explode=(0,0,0,0.1),startangle=90,colors=['#1F3B73','#555555','#2AA198','#F29C11'])
plt.title("Platform-wise Total Time Spent",fontsize=18,color='#1F3B73',fontweight='bold',fontname='Calibri')
plt.savefig('Platform.png',dpi=300)
plt.show()

# %% [markdown]
# ##### * Facebook has the highest share (26%) of total time spent.
# ##### * Instagram has the lowest share (24%).
# ##### * YouTube and TikTok are nearly equal, each with 25%.
# ##### **Overall: Time spent is almost evenly distributed, but Facebook slightly dominates.**

# %% [markdown]
# ## Age & Gender Patterns

# %%
sns.boxplot(x="Gender", y="Total Time Spent", data=df,palette={'Male':'#1F3B73', 'Female':'#2AA198', 'Other':'#555555'})
plt.title("Total Time Spent by Gender", fontsize=18, color='#1F3B73', fontweight='bold')
plt.xlabel("Gender", fontsize=14, color='#333333')
plt.ylabel("Total Time Spent", fontsize=14, color='#333333')
plt.xticks(fontsize=12, color='#555555')
plt.yticks(fontsize=12, color='#555555')
plt.savefig('Gender vs. Total Time Spent.png',dpi=300)
plt.show()

# %%
sns.lineplot(x="Age", y="Total Time Spent", hue="Gender", data=df)
plt.show()

# %%
colors = {"Male": "blue", "Female": "red", "Other": "green"}

plt.scatter(df["Age"], df["Total Time Spent"], 
            c=df["Gender"].map(colors), alpha=0.6)

plt.xlabel("Age")
plt.ylabel("Total Time Spent")
plt.title("Age vs Total Time Spent by Gender")
plt.show()

# %% [markdown]
# ##### * Time spent is quite similar across genders, with no major differences.
# ##### * Age does not show a consistent impact on time spent.
# ##### * Usage patterns are widely spread out, with no clear correlation to age or gender.
# ##### **Conclusion: Neither age nor gender strongly influences total time spent.**

# %% [markdown]
# ## Income & Debt vs. Social Media Usage

# %%
sns.scatterplot(x="Income", y="Addiction Level", size="Debt", hue="ProductivityLoss", data=df,palette="viridis",alpha=0.8,edgecolor='k')
plt.title("Income vs Addiction Level", fontsize=18, color='#1F3B73', fontweight='bold')
plt.xlabel("Income", fontsize=14, color='#333333')
plt.ylabel("Addiction Level", fontsize=14, color='#333333')
plt.xticks(fontsize=12, color='#555555')
plt.yticks(fontsize=12, color='#555555')
plt.savefig('Income & Debt vs. Social Media Usage.png',dpi=300)
plt.show()

# %% [markdown]
# ##### * Lower income → Higher addiction, more debt, and greater productivity loss
#
# ##### * Higher income → Lower addiction, less debt, and lower productivity loss
#
# ##### * Addiction is strongly linked to debt and productivity loss
#
# ##### **Overall: Higher social media addiction is linked to lower income, higher debt, and greater productivity loss, while those with higher income tend to have lower addiction, less debt, and better productivity.**

# %% [markdown]
# ## Device & OS Usage Impact

# %%
plt.figure(figsize=(8,6))
sns.countplot(x='DeviceType', hue='OS', data=df,
              palette=['#2AA198', '#1F3B73', '#F29C11', '#555555'])

plt.title("Device & OS Usage", fontsize=18, color='#1F3B73', fontweight='bold')
plt.xlabel("Device", fontsize=14, color='#333333')
plt.ylabel("User Count", fontsize=14, color='#333333')
plt.xticks(fontsize=12, color='#555555')
plt.yticks(fontsize=12, color='#555555')
plt.legend(title='OS', fontsize=12, title_fontsize=13)
plt.tight_layout()
plt.savefig('Device & OS Usage.png',dpi=300)
plt.show()

# %%
df.groupby("DeviceType")["Total Time Spent"].mean().plot(kind="bar",stacked=True,color=['#2AA198', '#1F3B73', '#F29C11', '#555555'],figsize=(8,6))
plt.title("Device-wise Time Spent", fontsize=18, color='#1F3B73', fontweight='bold')
plt.xlabel("Device Type", fontsize=14, color='#333333')
plt.ylabel("Avg Time Spent", fontsize=14, color='#333333')
plt.xticks(rotation=0,fontsize=12, color='#555555')
plt.yticks(fontsize=12, color='#555555')
plt.yticks(fontsize=12, color='#555555')
plt.show()

# %% [markdown]
# ##### 1. Device Popularity:
#
# * Smartphones are the most used device, especially with Android and iOS.
# * Computers are used mainly with Windows and MacOS.
# * Tablet usage is lower overall.
#
# ##### 2. Time Spent:
#
# * Time spent is almost equal across all devices (Computer, Smartphone, Tablet).
# * Despite lower tablet usage, average time spent is comparable to other devices.
#
# ##### **Overall: People spend similar amounts of time on all device types, but smartphones are the most commonly used, especially with Android.**

# %% [markdown]
# ## Content Consumption & Engagement

# %%
plt.figure(figsize=(12,5))
sns.barplot(
    x="Video Category", 
    y="Time Spent On Video", 
    data=df,
    palette = ['#2AA198', '#1F3B73', '#F29C11', '#555555', '#8B0000', '#FFC300', '#00CED1', '#FF69B4', '#708090'] 
)

plt.title("Video Category vs Time Spent", fontsize=18, color='#1F3B73', fontweight='bold')
plt.xlabel("Video Category", fontsize=14, color='#333333')
plt.ylabel("Time Spent (minutes)", fontsize=14, color='#333333')

plt.xticks(fontsize=12, color='#555555')
plt.yticks(fontsize=12, color='#555555')

plt.tight_layout()
plt.savefig('Content_Engagement.png', dpi=300)
plt.show()

# %% [markdown]
# ##### * Pranks and Vlogs have the highest average time spent (~16–17 minutes).
#
# ##### * Trends has the lowest average time spent (~14 minutes).
#
# ##### * Other categories (Gaming, Jokes/Memes, Entertainment, ASMR, Life Hacks, Comedy) fall in the middle (~14–15.5 minutes).
#
# ##### * Overall, viewers spend slightly more time on entertaining content (Pranks, Vlogs, Entertainment) than on casual/trendy content (Trends, ASMR, Life Hacks).

# %%
sns.scatterplot(x="Video Length", y="Engagement", data=df)
plt.title("Video Length vs Engagement")
plt.show()

# %% [markdown]
# ##### 1. **Time spent on videos** is fairly consistent across categories, with most viewers spending around 10–25 minutes regardless of content type.
#
# ##### 2. **Comedy videos** tend to have lower viewing times compared to others, suggesting they are shorter or consumed more briefly.
#
# ##### 3. **Vlogs** and **Entertainment videos** generally keep viewers engaged for longer durations.
#
# ##### 4. **Engagement** does not show a clear pattern with **video length** — both short and long videos can have high or low engagement, implying that length alone doesn't determine user interaction.
#
# ##### **Overall: Viewer time is consistent across most categories, with Comedy watched for shorter durations. Video length doesn’t significantly impact engagement, suggesting content quality matters more than duration.**

# %% [markdown]
# ## Addiction & Self-Control Analysis

# %%
sns.scatterplot(x="Self Control", y="Addiction Level", hue="Frequency", data=df)
plt.show()

# %% [markdown]
# ##### * Addiction levels decrease as self-control increases, showing a negative correlation.
#
# ##### * High addiction is mostly seen in individuals with low self-control (scores 3–5).
#
# ##### * Night-time users are more likely to have higher addiction levels.
#
# ##### * Morning and evening users tend to have higher self-control and lower addiction.
#
# ##### **Overall: Higher self-control is associated with lower addiction levels. Night-time usage is linked to higher addiction, while morning and evening users tend to show better self-control and lower addictive behavior.**

# %% [markdown]
# ## Productivity Loss Estimation

# %%
sns.histplot(df['ProductivityLoss'], bins=20, kde=True)
plt.show()

# %%
plt.scatter(df["Total Time Spent"], df["ProductivityLoss"])
plt.xlabel("Total Time Spent")
plt.ylabel("Productivity Loss")
plt.title("Time Spent vs Productivity Loss")
plt.show()

# %% [markdown]
# ##### * Productivity loss values are mostly concentrated around the middle range (especially 5 and 6).
#
# ##### * The data shows discrete productivity levels with multiple peaks, suggesting common specific values.
#
# ##### * There's no clear relationship between total time spent and productivity loss.
#
# ##### * Time spent varies widely across all productivity loss levels.
#
# ##### * Other factors may be influencing productivity loss beyond just time spent.
#
# ##### **Overall: Productivity loss is not directly related to time spent, indicating other factors are driving the loss.**

# %% [markdown]
# ## Importance Score & Watch Reason

# %%
sns.boxplot(x="Watch Reason", y="Importance Score", data=df)
plt.show()

# %%
df.groupby("Watch Reason")["Importance Score"].mean().plot(kind="bar")
plt.title("Watch Reason vs Importance Score")
plt.xlabel("Watch Reason")
plt.ylabel("Avg Importance Score")
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# ##### * Importance scores are similarly distributed across all watch reasons (Procrastination, Habit, Entertainment, Boredom).
#
# ##### * The average importance scores for each watch reason are nearly the same, all around 5.
#
# ##### * No watch reason stands out as significantly more or less important than the others.
#
# ##### **The overall conclusion is that all watch reasons—procrastination, habit, entertainment, and boredom—are equally important in influencing the behavior, with no single reason dominating the others.**

# %% [markdown]
# ## Behavioral & Motivational Factors (Combined Bubble Chart)

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(
    x="Addiction Level",
    y="ProductivityLoss",
    size="Debt",                   
    hue="Watch Reason",            
    data=df,
    palette={'Procrastination':'#2AA198', 'Habit':'#F29C11', 'Entertainment':'#1F3B73', 'Boredom':'#555555'},
    sizes=(50,300),
    alpha=0.7,
    edgecolor='k'
)

plt.title("Behavioral & Motivational Factors", fontsize=18, color='#1F3B73', fontweight='bold')
plt.xlabel("Addiction Level", fontsize=14, color='#333333')
plt.ylabel("Productivity Loss", fontsize=14, color='#333333')

plt.xticks(fontsize=12, color='#555555')
plt.yticks(fontsize=12, color='#555555')

plt.legend(title="Watch Reason & Debt", fontsize=12, title_fontsize=13, loc='best')

plt.tight_layout()
plt.savefig('Behavioral_Motivation.png', dpi=300)
plt.show()

# %% [markdown]
# ##### * Higher addiction levels are linked with lower productivity.
# ##### * Procrastination and habit are strong reasons for video watching across addiction levels.
# ##### * Entertainment becomes more common at higher addiction levels (with lowest productivity).
# ##### * Debt factor (True/False) doesn’t show a strong visible clustering but appears more at mid–high addiction.

# %% [markdown]
# ## Network & Connection Type Influence

# %%
sns.barplot(x="ConnectionType", y="Total Time Spent", data=df,estimator="mean",palette=['#1F3B73', '#F29C11'])
plt.title("Connection Type vs Time Spent", fontsize=18, color='#1F3B73', fontweight='bold')
plt.xlabel("Connection Type", fontsize=14, color='#333333')
plt.ylabel("Average Time Spent", fontsize=14, color='#333333')
plt.xticks(fontsize=12, color='#555555')
plt.yticks(fontsize=12, color='#555555')
plt.savefig('Connection Type.png',dpi=300)
plt.show()

# %% [markdown]
# ##### * Users spend slightly more total time using Mobile Data compared to Wi-Fi.
#
# ##### * The difference in time spent between Mobile Data and Wi-Fi is small but consistent.
#
# ##### * Both connection types show relatively similar usage patterns in terms of total time spent.
#
# ##### **Overall: Connection type has minimal impact on total time spent, with mobile data showing slightly higher usage than Wi-Fi.**

# %% [markdown]
# ## Gender-wise Age Comparison Across Social Media Platforms

# %%
plt.figure(figsize=(10,7))
sns.barplot(x='Platform',y='Age',data=df,hue='Gender')
plt.show()

# %% [markdown]
# ##### * Instagram shows the most age variation by gender — males are older.
#
# ##### * Facebook, YouTube, and TikTok have similar average ages across all genders.
#
# ##### * "Other" gender users tend to be slightly younger overall.
#
# ##### **Overall: Across major social media platforms, average user age is generally consistent across genders, with only slight variations. Instagram stands out with a noticeable age gap among genders, while Facebook, YouTube, and TikTok show minimal differences.**

# %% [markdown]
# ## Social Media Usage by Age

# %%
sns.scatterplot(x='Age',y='Total Time Spent',data=df)
plt.show()

# %% [markdown]
# ##### * No strong correlation between age and time spent on social media.
#
# ##### * High and low usage exists across all age groups.
#
# ##### * Social media is used heavily by both younger and older individuals.
#
# ##### **Overall: Social media usage is highly variable and not strongly age-dependent — people of all ages spend both low and high amounts of time on social media.**

# %% [markdown]
# ## Distribution of Numeric Features in the Dataset

# %%
df.hist()
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### * Most features (like **Age**, **Total Time Spent**, **Income**) are fairly uniformly distributed.
#
# ##### * **Scroll Rate**, **Number of Videos Watched**, and **Video Length** show slight right skew.
#
# ##### * **Self Control**, **Addiction Level**, and **Satisfaction** show peaks at lower values, indicating potential behavioral patterns.
#
# ##### * **Productivity Loss** and **Engagement** vary widely, with multiple peaks.
#
# ##### * **Time Spent on Work** is more concentrated in the lower to mid-range.

# %% [markdown]
# ## Distribution of Total Time Spent on Social Media

# %%
sns.boxplot(x=df['Total Time Spent'])
plt.show()

# %% [markdown]
# ##### 1. **Median Time Spent**: The median (middle line in the box) is around 150 minutes, indicating the typical time users spend on social media.
#
# ##### 2. **Interquartile Range (IQR)**:
# * The box spans from roughly 75 minutes (Q1) to 225 minutes (Q3).
# * This means 50% of the users spend between 75 to 225 minutes on social media.
#
# ##### 3. **No Outliers**:
# * There are no dots outside the whiskers, indicating no significant outliers.
#
# ##### 4. **Whiskers Range**:
# * The minimum and maximum times are close to 0 and 300 minutes, respectively.
#
# ##### **Conclusion: Most users spend between 75 and 225 minutes on social media, with a median of ~150 minutes, and there are no extreme values or outliers in the data.**

# %% [markdown]
# ## Distribution of Productivity Loss Among Users

# %%
sns.violinplot(x=df['ProductivityLoss'])
plt.show()

# %% [markdown]
# ##### * Most common productivity loss values are between 3 and 7.
#
# ##### * Distribution is multimodal, showing several peaks in user responses.
#
# ##### * Symmetrical spread with no extreme outliers.
#
# ##### * Indicates varied but centered productivity loss among users.
#
# ##### **Overall: Most users spend 75–225 minutes on social media, leading to moderate productivity loss (3–7 range). Time spent is likely linked to reduced productivity.**

# %% [markdown]
# ## Addiction Level vs Usage Frequency by Gender

# %%
sns.lineplot(x='Frequency',y='Addiction Level',data=df,marker='*',hue='Gender')
plt.show()

# %% [markdown]
# ##### * Addiction levels are highest at night across all genders.
#
# ##### * Addiction levels decrease steadily from night → afternoon → evening → morning.
#
# ##### * Females show slightly higher addiction in the afternoon and morning than others.
#
# ##### * All genders follow a similar downward trend in addiction with time of day.
#
# ##### **Overall: Addiction is highest at night and decreases by morning across all genders, with females showing slightly higher daytime addiction.**

# %% [markdown]
# ## Number of Users by Location

# %%
plt.figure(figsize=(12,5))
sns.countplot(x='Location',data=df)
plt.show()

# %% [markdown]
# ##### * **India** has the highest number of users by a significant margin.
#
# ##### * The **United States** comes second, with a high user count but still noticeably less than India.
#
# ##### * **Germany** has the lowest user count among the listed countries.
#
# ##### * Most other countries (Pakistan, Mexico, Brazil, Vietnam, Indonesia, Philippines, Japan) have similar and moderate user counts.
#
# ##### **Overall: India and the United States lead in user numbers, while other countries show relatively even and lower distributions.**

# %% [markdown]
# ## Platform-wise Relationship Between Sessions and Time Spent

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x='Number of Sessions', y='Total Time Spent', hue='Platform', data=df, alpha=0.6)
plt.title("Total Time Spent vs Number of Sessions by Platform")
plt.show()

# %% [markdown]
# ##### * **Positive Trend**: Generally, as the number of sessions increases, the total time spent also increases across all platforms.
#
# ##### * **Wide Variability**: There's a wide range of time spent for the same number of sessions, indicating user behavior differs significantly even with similar session counts.
#
# ##### * **Platform Distribution**: All platforms (Instagram, Facebook, YouTube, TikTok) appear fairly evenly distributed, with no single platform dominating across all session levels.
#
# ##### * **High Usage**: Some users spend close to or over 300 units of time, regardless of platform, especially as session count rises.
#
# ##### **Overall: More sessions usually mean more total time spent, but user behavior varies, and all platforms show similar engagement patterns overall.**

# %% [markdown]
# ## 📊 Overall Findings
#
# ### 1. Platform-Wise Usage Patterns
#
# * Facebook consumes the most user time (26%), slightly dominating over other platforms.
# * YouTube and TikTok have nearly equal usage (25% each), while Instagram has the lowest share (24%).
# * Overall, time spent is fairly evenly distributed across platforms, indicating that multiple platforms contribute to social media time-wasting.
#
# ### 2. Demographic Influences
#
# * Age and Gender: Time spent on social media is similar across all genders and shows no consistent pattern with age, suggesting these factors do not strongly influence usage.
# * Income & Debt: Lower-income users tend to have higher social media addiction, more debt, and greater productivity loss. Higher-income users show lower addiction, less debt, and better productivity.
# * Overall, social media addiction and productivity loss are more closely linked to income than to age or gender.
#
# ### 3. Device, OS, and Connectivity Factors
#
# * Device Usage: Smartphones are the most commonly used devices, especially with Android and iOS, while computers and tablets have lower usage.
# * Time Spent: Despite differences in device popularity, average time spent is similar across smartphones, computers, and tablets.
# * Connectivity: Users spend slightly more time on mobile data than Wi-Fi, but the difference is minimal.
# * Overall, device type and connection type have a minor impact on total time spent, with smartphones being the primary medium.
#
# ### 4. Content Engagement and Behavioral Impacts
#
# * Content Type: Viewer engagement is fairly consistent across most video categories, except comedy, which tends to have shorter viewing durations. Video length alone does not determine engagement.
# * Addiction & Self-Control: Higher self-control is associated with lower addiction levels. Night-time users show higher addiction, while morning and evening users tend to have lower addiction.
# * Productivity Loss: Productivity loss is not directly related to total time spent, indicating other behavioral factors contribute to reduced productivity.
# * Watch Reasons: Procrastination, habit, entertainment, and boredom are equally important in influencing viewing behavior.
# * Overall, engagement and productivity outcomes are driven more by content type, self-control, and usage patterns than by sheer time spent.

# %% [markdown]
# ## 🎯 Final Overall Insight
#
# Social media time-wasting is multi-dimensional:
#
# * Facebook dominates, but overall platform usage is balanced.
# * Age and gender have little impact on usage.
# * Lower income and low self-control link to higher addiction and productivity loss.
# * Content quality, habits, and time-of-day drive engagement more than device or video length.

# %% [markdown]
# ## 📌 Recommendations
#
# ### 1. Platform-Wise Usage
#
# * Encourage users to set daily limits on high-usage platforms like Facebook to reduce overall screen time.
# * Use app timers or alerts to promote balanced platform usage.
#
# ### 2. Demographic Influences
#
# * Implement targeted awareness programs for lower-income users highlighting the risks of excessive social media use, debt, and productivity loss.
# * Promote digital well-being campaigns across all age groups, even though age and gender are not major factors.
#
# ### 3. Device, OS, and Connectivity Factors
#
# * Promote responsible smartphone use since it is the most commonly used device.
# * Encourage breaks and diversified activities regardless of device type or connection type to reduce passive scrolling.
#
# ### 4. Content Engagement and Behavioral Impacts
#
# * Encourage users to prioritize meaningful content over mindless consumption.
# * Promote strategies to improve self-control, such as scheduled usage times, especially for night-time users.
# * Educate users on managing addictive behaviors and understanding personal usage patterns.
# * For content creators: focus on quality over length, as engagement is influenced more by content quality than video duration.

# %% [markdown]
# ## 🎯 Final Actionable Insight
#
# Curbing social media time-wasting requires a multi-pronged approach:
#
# * Limit usage of high-traffic platforms like Facebook.
# * Promote self-control and healthy social media habits.
# * Prioritize engaging and meaningful content over passive scrolling.
# * Raise awareness among lower-income and high-addiction users about risks and productivity loss.
